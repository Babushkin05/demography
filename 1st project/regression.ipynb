# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_spss('r32h_os.sav')
data
# Out:
#       bbredid_h      bbid_h      aaid_h       zid_h       yid_h       xid_h  \
# 0         663.0     10003.0     10003.0     10003.0     10003.0     10003.0
# 1         666.0     10014.0     10014.0     10014.0     10014.0     10014.0
# 2         667.0     10016.0     10016.0     10016.0     10016.0     10016.0
# 3         668.0     10018.0         NaN         NaN         NaN         NaN
# 4         669.0     10023.0         NaN         NaN         NaN         NaN
# ...         ...         ...         ...         ...         ...         ...
# 4783     6648.0  14290013.0  14290013.0  14290013.0  14290013.0  14290013.0
# 4784     6649.0  14290014.0  14290014.0  14290014.0  14290014.0  14290014.0
# 4785     5287.0  14290015.0  14290015.0  14290015.0  14290015.0  14290015.0
# 4786     6650.0  14290017.0  14290017.0  14290017.0  14290017.0  14290017.0
# 4787     6651.0  14290018.0  14290018.0  14290018.0  14290018.0  14290018.0
#
# ...

# %%
X = data[[x for x in list(data.columns) if 'bbf' in x]]
X
# Out:
#      bbf3 bbf4 bbf5 bbf6.1 bbf7.1 bbf6.2 bbf7.2 bbf8 bbf9.1a bbf9.1b  ...  \
# 0     Нет  NaN  Нет    NaN    NaN    NaN    NaN  Нет     NaN     NaN  ...
# 1     Нет  NaN  Нет    NaN    NaN    NaN    NaN  Нет     NaN     NaN  ...
# 2     Нет  NaN  Нет    NaN    NaN    NaN    NaN  Нет     NaN     NaN  ...
# 3     Нет  NaN  Нет    NaN    NaN    NaN    NaN   Да     Нет     NaN  ...
# 4     Нет  NaN  Нет    NaN    NaN    NaN    NaN   Да     Нет     NaN  ...
# ...   ...  ...  ...    ...    ...    ...    ...  ...     ...     ...  ...
# 4783  Нет  NaN  Нет    NaN    NaN    NaN    NaN  Нет     NaN     NaN  ...
# 4784  Нет  NaN  Нет    NaN    NaN    NaN    NaN  Нет     NaN     NaN  ...
# 4785  Нет  NaN  Нет    NaN    NaN    NaN    NaN  Нет     NaN     NaN  ...
# 4786  Нет  NaN  Нет    NaN    NaN    NaN    NaN   Да     Нет     NaN  ...
# 4787  Нет  NaN  Нет    NaN    NaN    NaN    NaN  Нет     NaN     NaN  ...
#
#      bbf14.12         bbf14.13 bbf14.14 bbf14.15     bbf14        bbf16.1  \
# ...

# %%
Y = data[['bbb1.o','bbb1.n']]
Y['bbb1.n'] = Y['bbb1.n'].fillna(0)
Y['bbb1.o'] = Y['bbb1.o'].fillna(0)
Y['family_size'] = Y['bbb1.o'] + Y['bbb1.n']
Y = Y['family_size']
Y
# Out:
# /var/folders/k3/d595fscx0sd4p776t_nkpc3h0000gn/T/ipykernel_61253/3587609887.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y['bbb1.n'] = Y['bbb1.n'].fillna(0)
# /var/folders/k3/d595fscx0sd4p776t_nkpc3h0000gn/T/ipykernel_61253/3587609887.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y['bbb1.o'] = Y['bbb1.o'].fillna(0)
# /var/folders/k3/d595fscx0sd4p776t_nkpc3h0000gn/T/ipykernel_61253/3587609887.py:4: SettingWithCopyWarning:
# ...
